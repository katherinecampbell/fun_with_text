# %%
# http://andybromberg.com/sentiment-analysis-python/
# Andy Bromberg's Simple Sentiment Analysis System
# Uses data from Pang & Lee (2005)
# Uses a Naive Bayes Classifier Train the System
#  NB Updated 2016 for package changes around scores

import re, math, collections, itertools, sys, os
import nltk, nltk.classify.util, nltk.metrics
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords
from nltk.metrics import BigramAssocMeasures, scores
from nltk.probability import FreqDist, ConditionalFreqDist

# %%
def TagWords(sentence):
    a = list()
    try:
            tagged = nltk.pos_tag(sentence)
            for item in tagged:
                if item[1][0] == 'U': #interjection
                      a.append(item[0])
                elif item[1][0] =='V': #verbs
                    a.append(item[0])
                elif item [1][0] == 'R': #adverbs
                    a.append(item[0])
                elif item [1][0] == 'J': #adjectives
                    a.append(item[0])
    except Exception as e:
        print(str(e))
    print(a)
    return (a)

# %%
#function extracts all verbs, adjectives,interjections and adverbs from a list
def get_v_adj_adv_interjection(text):
    picked_words = []
    for item in text:
        if item[1] == 'UH':#interjection
            print ('ITEM IS', item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'JJ':#j is adj
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'JJR':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'JJS':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'RB':
            print (item)#rb is adv
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'RBR':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'RBS':
            print ('item is', item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'VB':
            print (item)#base verb
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'VBD':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'VBG':
            print (item)
            picked_words.append(item[0])
        elif item [1] == 'VBN':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item[1]== 'VBP':
            print (item)
            print('word is ', item[0])
            picked_words.append(item[0])
        elif item [1] == 'VBZ':
            print(item)
            print('word is ', item[0])
            picked_words.append(item[0])
        print ('words are', picked_words)
    return picked_words

# %%
def evaluate_features(feature_select):
    #reading pre-labeled input and splitting into lines
    negSentences = open('rt-polarity-neg.txt', 'r', encoding='utf8')
    posSentences = open('rt-polarity-pos.txt', 'r', encoding='utf8')
    negSentences = re.split(r'\n', negSentences.read())
    posSentences = re.split(r'\n', posSentences.read())
    stops = set(stopwords.words("english"))
    posFeatures = []
    negFeatures = []
    # breaks up the sentences into lists of individual words
    # creates instance structures for classifier
    for i in posSentences:
        posWords = re.findall(r"[\w']+|[.,!?;]", i)
        #posWords = [word for word in posWords if word not in stops] #take out stop words
        posWords = TagWords(posWords)
        posWords = [feature_select(posWords), 'pos']
        posFeatures.append(posWords)
    for i in negSentences:
        negWords = re.findall(r"[\w']+|[.,!?;]", i)
        #negWords= [word for word in negWords if word not in stops]
        negWords = TagWords(negWords)
        negWords = [feature_select(negWords), 'neg']
        negFeatures.append(negWords)
        
    posCutoff = int(math.floor(len(posFeatures)*3/4))
    negCutoff = int(math.floor(len(negFeatures)*3/4))
    trainFeatures = posFeatures[:posCutoff] + negFeatures[:negCutoff]
    testFeatures = posFeatures[posCutoff:] + negFeatures[negCutoff:]
    
    #Runs the classifier on the testFeatures
    classifier = NaiveBayesClassifier.train(trainFeatures)
    
    #Sets up labels to look at output
    referenceSets = collections.defaultdict(set)
    testSets = collections.defaultdict(set)
    for i, (features, label) in enumerate(testFeatures): # enumerate adds number-count to each item
        referenceSets[label].add(i)               # recorded polarity for these test sentences
        predicted = classifier.classify(features) # classifiers' proposed polarity for tests
        testSets[predicted].add(i)

    #Outputs
    print('train on %s instances, test on %s instances'% (len(trainFeatures), len(testFeatures)))
    print('accuracy:', nltk.classify.util.accuracy(classifier, testFeatures))
    print('pos precision:', scores.precision(referenceSets['pos'], testSets['pos']))
    print('pos recall:', scores.recall(referenceSets['pos'], testSets['pos']))
    print('neg precision:', scores.precision(referenceSets['neg'], testSets['neg']))
    print('neg recall:', scores.recall(referenceSets['neg'], testSets['neg']))
    classifier.show_most_informative_features(10)

def make_full_dict(words):
    return dict([(word, True) for word in words])

print('using all words as features')
evaluate_features(make_full_dict)
# Out:
# using all words as features
# ['destined', "century's", 'new', 'going', 'make', 'splash', 'even', 'greater', 'arnold', 'jean', 'steven']
# ['gorgeously', 'elaborate', 'rings', 'huge', 'cannot', 'adequately', 'describe', 'co', 'expanded', 'middle']
# ['effective']
# ['sometimes', 'go', 'fun', 'wasabi', 'good']
# ['rare', 'issue', "that's", 'keenly', 'observed', "doesn't"]
# ['provides', 'great', 'insight', 'neurotic', 'even', 'reached', 'absolute', 'top']
# ['rare']
# ['perhaps', 'ever', 'made', 'literally', 'showed', 'paved', 'good']
# ['turns', 'snappy', 'edges', "it's", 'want']
# ['take', 'offers', 'refreshingly', 'different', 'asian']
# ['well', 'seeing', 'talking', 'singing']
# ['really', 'surprises', 'low', 'key', 'genuine']
# ['go']
# ['greatest', 'oriented', 'fantasy', 'ever']
# ['ultimately', 'need', 'much']
# ['utterly', 'compelling', "'who", 'wrote', "it'", 'famous', 'ever', 'lived', 'comes']
# ['illuminating', 'overly', 'talky']
# ['masterpiece', 'making']
# ['enrapturing', 'willing', 'inscrutable']
# ['breath', 'fresh', 'true']
# ['thoughtful', 'provocative', 'insistently', 'humanizing']
# ['includes', 'top', 'working', 'independent', 'lovely', 'amazing', 'incisive', 'bleakly', 'amusing', 'go']
# ['disturbing', 'frighteningly', 'evocative', 'hypnotic', 'composed', 'philip']
# ["it's", 'nice', 'moviegoing']
# ['dedicated', 'good', 'hearted']
# ['occasionally', 'melodramatic', 'also', 'extremely', 'effective']
# []
# ['idealistic', 'brings', 'old', 'romantic']
# ['maintains', 'brisk', 'familiar', 'however', 'lacks', 'often', 'associated', "stevenson's", 'well', 'earlier']
# ['helps', 'lil', 'pint', 'sized', 'play', 'real']
# ['guaranteed', 'ever', 'shook', 'rattled', 'rolled']
# ['masterful', 'unique', 'deceptive', 'compelling', 'fatalist']
# ['forgettable']
# ["there's", 'effectively', 'teach', 'think', "it's", 'unfortunately', 'rated', 'paid']
# ['easy', 'give', 'crush', 'new', 'funeral', "it's", 'far', 'thoughtful']
# ['literate', 'smart', 'never', 'took', 'always', 'seemed', 'static']
# ['perfectly', 'captures', 'roadside']
# ['wierzbicki', 'almost', 'spooky', 'calculating', 'lolita']
# ['best', 'distinguished', 'distinctive', 'fide', 'fascinating', 'replete', 'willing', 'make']
# ['recent', 'outlandish', 'heavy', 'beginning', 'creep']
# ['draws', 'acts', 'better', 'known', 'co']
# ['loses', 'bite', 'last', 'happy', 'ending', "that's", 'even', 'less', 'plausible', 'much', 'refreshingly', 'novel']
# ['surely', 'called', 'exhilarating', 'great']
# ['el', 'que', 'vale']
# ['makes', 'strong', 'creating', 'motown']
# ['lips', 'chanting', 'long', 'braided', 'little', 'wipe', 'away', 'jeweled']
# ['gosling', 'provides', 'amazing', 'else']
# ['real', 'real', 'gives', 'rare', 'glimpse', "don't", 'know']
# ['yet', 'lacerating', 'darkly']
# ['spoofing', 'easy', 'old', 'giant', 'acknowledges', 'celebrates', 'cheesiness', 'get', 'kick']
# ['engaging', "johnson's", 'eccentric']
# ['ragged', 'cheap', 'unassuming']
# ['much', 'charisma', "you'd", 'happy', 'listen', 'reading', 'hugh', 'likeable']
# ['beautifully', 'orchestrates', 'chilly', 'neurotic', 'absorbed', 'martha', 'begins', 'open']
# ['snow', 'lovable', 'siberian', 'parka', 'wrapped', 'dose']
# ['everytime', 'think', 'undercover', 'finds', 'new']
# ['original', 'even', 'many']
# ['bryan', 'slew', 'potential', 'simply', 'intrusive', 'whole', 'certainly', 'captures', 'intended', 'spirit']
# ["you'd", 'enough', 'plucky', 'british', 'still', 'charming']
# ['enlightened', "derrida's", 'derrida', 'undeniably', 'fascinating', 'playful']
# ['pleasant', 'enough', 'held', 'together', 'skilled', 'ensemble']
# ['best', 'american', 'troubled']
# ['always', 'hit', 'miss', 'beloved', "kids'", 'tuck', 'everlasting', 'little']
# ['involved', 'creating', 'layered', 'light']
# ['animated', 'keenly', 'depicts', 'inner', 'adolescent', 'uncontrolled', 'intense']
# ['invincible', 'alive', 'well', 'living']
# ['great', 'actress', 'complex', 'morvern', 'callar', 'less', 'compelling', 'farther', 'shocking']
# ['obvious', 'humour']
# ['good', 'half', 'long', 'comes', 'replete', 'flattering']
# ['simmering', 'psychological', 'bursts', 'sudden', 'startling', 'slow', 'preceded']
# ['intelligent', 'psychological']
# ['compelling', 'coming', 'arduous', 'sensitive', 'young', 'fierce', 'struggle', 'free', 'dangerous', 'domineering']
# ['truly', 'moving', 'perfect', 'done', 'right', 'heal', 'clarify']
# ['delicately', 'observed', 'deeply', 'felt', 'masterfully', 'stylized', 'maverick']
# ['deftly', 'wrought', 'richer', 'work', 'coloring', 'rather']
# ['expanded', 'either', 'loving', 'rolling', 'loved', 'incredible']
# ['ingeniously', 'constructed']
# ['page', "can't", 'see', 'happens', 'next']
# ['challenges', 'confront', 'sexual']
# ['absorbing', 'disturbing', 'perhaps', 'disturbing', 'originally', 'intended', 'little', 'gone', 'long']
# ['best', 'far', 'benchmark', 'best', 'measured']
# ['painful', 'willing', 'take', 'rewarded', 'accomplished', 'riveting']
# ['startling', 'gives', 'fascinating', 'depressing', 'iranian', 'rural', 'close', 'iraqi']
# ['imaginative']
# ['aside', 'narc', 'gritty', 'gets']
# ['isle', 'preposterous', 'thoroughly', 'misogynistic', 'vistas', 'incredibly', 'beautiful']
# ['together', 'tok', 'darkly', 'funny', 'still', 'lot']
# ['kapur', 'filmmaker', 'real', 'epic', 'landscapes', 'better', 'earlier', 'english', 'overpraised']
# ['educational', 'escort', 'entire']
# ['exciting']
# ['directs', 'well', 'gets', 'nice', 'absorbs', "movie's", 'uses', "damon's", 'focused', 'sincere']
# ['still', 'intact']
# ['uses', 'archival', 'horrifying', 'still', 'photographs', 'charming', 'old', 'meeropol', 'entertaining', 'create', 'song', 'powerful']
# ['almost', 'anthropologically', 'detailed', 'early', "it's", 'significant', 'overstated']
# ["mcfarlane's", 'firmly', 'coming', 'also', 'jarring', "it's", 'hard', 'get', 'back', "boys'"]
# ['else', 'unusual', 'psychological']
# ['normal', 'barely', 'enough', 'sustain', 'interstitial', 'imax', 'disappear', 'vertiginous', 'opened']
# ['imaginatively', 'fans', 'dormant', 'national', 'calcified', 'chronic']
# []
# ['enjoyed', 'surprised', 'quickly', 'faded']
# ['chicago', 'sophisticated', 'brash', 'sardonic', 'completely', 'joyful']
# ['steve', 'ernest', 'hemmingway', 'accelerated']
# ['refreshing', 'korean', 'female', 'high', 'face', 'uphill', 'take', 'deeper']
# ["it's", 'run', 'common', 'earlier', 'double']
# ['held', 'together', 'previous', 'sacrifice', 'patience']
# ['possible', 'original']
# ['romantic', 'operates', 'contained']
# ['blue', 'drink', "it's", 'ultimate']
# ['often', 'filled', 'often', 'seen', "today's"]
# ['tempting', 'regard', 'andrew', "earnhart's", 'quizzical', 'charming', 'allows', 'see', 'finally']
# ['feel', 'good', 'best']
# ['edited', 'syncopated', 'mimicking', 'turns', 'documentary', 'making', 'invigorating', 'lacking', 'mtv']
# ['mostly', 'intelligent', 'engrossing', 'psychologically', 'resonant']
# ["it's", 'gives', 'secret', 'intermittent', 'reaffirming', 'long', 'held', 'indeed', 'erasing']
# ["it's"]
# ['takes', "kurys'", 'whole', 'new']
# ['dramatic', 'wrenching', "it's", 'compelling', 'mainly', "it's", 'told']
# ['personal', 'regarding', 'means', 'big', 'iconic', 'gambol', 'fluidly', 'charming']
# ['compassionate']
# ['somewhere', 'short', 'modern', 'b', 'funny', 'agreeably', 'unpretentious', 'spend']
# ['digital', 'documentary', 'great', 'glimpse', 'different']
# ['teen', 'swimming', 'takes', 'tell', 'casts', 'mostly', 'little', 'known', 'key', 'intriguing']
# ['playful', 'constantly', 'frustrates', 'know', 'deconstructing', 'format', 'doubtless', 'give']
# ['extreme', 'exceeds', 'good', 'good', 'good', 'good', 'good', 'good']
# ['hear', 'suffering', 'still', 'unaffected']
# ['thunderous', 'first', 'quiet', 'pure', 'far', 'shortage', 'dilutes', 'otherwise', 'respectable', 'still', 'flick', 'truly', 'excellent']
# ['obviously', 'struck', 'responsive', 'many', 'south']
# ['see', 'barbed', 'bracing', 'big']
# ['classy', 'left', 'still', 'chops', 'drive', 'done']
# ["fessenden's", 'proved', 'important', 'especially', 'finale']
# ['exactly', 'gourmet', 'even', 'coming']
# ['made', 'shut', 'real', 'take', 'vicarious', 'last', 'frontier']
# ['merely', 'technical', 'logistical', 'russian', 'cinematic']
# ['talented', 'terribly', 'charismatic', 'essential', 'stars', 'social']
# ["it's", 'great', 'sizzle', 'little', 'spectacular', 'fizz', 'infectious']
# ['original']
# ['delight', 'know']
# ['gloriously', 'goofy']
# ['regular', 'minefield', 'coming', 'potent', 'honesty']
# ["haven't", 'dulled', 'slasher', 'films', "you're", 'psychological']
# ['minor', 'sad', 'singles']
# ['intensely', 'personal', 'yet', 'deftly', 'shows']
# ['fi', 'special', 'cobbled', 'together', 'indulge', 'lucas', 'long', 'forgotten']
# ['win', 'succeed', 'following', 'feel', 'good', 'winning', 'offering', 'urban', 'welcome']
# ["it's", 'great', 'american', 'see', 'candidate', 'giving']
# ['far', 'perfect', 'right', 'innocent', 'well']
# ['superior', 'human', 'played', 'back', 'roads']
# ['waydowntown', 'perfect', 'boasts', 'huge']
# ['allen', 'great', 'never', 'hogs', 'fellow', 'good']
# ['enjoyable', 'conan', 'special', 'mummy', 'represent']
# ['enormously', 'likable', 'partly', 'aware', 'grasp']
# ["here's", 'british', 'gleefully', 'unconcerned', 'yet', 'determined']
# ["it's", 'old', 'lively', 'sharp', 'acting', 'partially', 'animated', 'make', 'kiss', 'seem', 'minty']
# ['seen', 'believed']
# ['patric', 'best', 'underwritten', 'fooled', 'deserves']
# ["yvan's", 'rambunctious', 'jewish', 'feels', 'funny', 'true']
# ['sweet', 'harmless']
# ["year's", 'happiest', 'real', 'subject', 'always', 'surprising']
# ["behan's", 'irish', 'general', 'rewarded', 'borstal']
# ['transparently', 'obvious', "it's", 'slowly', 'paced', "it's", 'worth', 'recommending', 'marvelous', 'michael', 'caine']
# ['faithful', 'presumes', "book's", 'premises', 'become', 'fleeting', 'precious', 'old']
# ["earnhart's", 'homespun', 'documentary', 'love']
# ['solidly', 'seaworthy']
# ['get', 'past', 'fantastical', 'harsh', 'isle', "you'll", 'flick', 'visual', 'likely', 'anywhere', 'else']
# ['many', 'ultimately', 'finds', 'human', "it's", 'welcome', 'genre', 'depend']
# ['well', 'made', 'certain', 'non', 'reactionary']
# ["there's", 'enough', 'make', 'educational', 'enough', 'make', 'unforgettable']
# ['solid', 'somewhat', 'heavy', 'handed', 'account', 'near', 'done', 'imaginative']
# ['follows', 'resolutely', 'realistic', 'uncompromising', 'insight', 'kurdish', "iran's"]
# ['good', 'running', 'trapped', 'effective', 'claustrophobic']
# ['captivating', 'romantic', 'welcome']
# ['nair', 'big']
# ['seaside', 'beautiful', 'nice', 'look', 'wait', 'going']
# ['rare', 'even', 'insight']
# ["willams'", 'best']
# ['engagingly', 'captures', 'maddening', 'magnetic']
# ['engrossing', 'buried', 'new']
# ["it's", 'traditional', "it's", 'done', 'careful', 'well', 'welcome']
# ['thoroughly', 'enjoyable']
# ['maybe', 'seen', 'worst', 'honestly', 'analyze', 'really', "isn't", 'bad']
# ['well', 'acted', 'character', 'driven', 'unexpected', 'feeling']
# ['simply', 'ever', 'documentary']
# ['funny']
# ['watching', 'aptly', 'enough', 'challenge', 'watching', 'great', 'tearing', 'landmark', 'riveting']
# ['cop', 'amazingly', 'well']
# ['best', 'understated', "nicholson's"]
# ['delivered', 'big', 'safe', 'old', 'travel', 'fame']
# ['outside', 'enjoy', 'close', "don't", 'really', 'want']
# ['nervous', 'give']
# ['watching', 'put', 'together', 'slasher', 'spare', 'borrowed', 'much', 'make']
# ['understand', 'happens', "i'm", 'sure', 'even', 'miyazaki', 'almost', 'certainly', 'fascinated', 'undoubtedly', 'delighted']
# ['fascinating']
# ['sophisticated', 'funny', 'good', 'natured', 'slight']
# ['insightful', 'oscar', 'nominated', 'ever', 'escalating', 'say', 'away', 'watchful', 'parental', 'gives', 'yet']
# ['admired']
# ['moved', 'love', 'bored', 'frustrated', 'still', 'feel']
# ['enough', 'heartbreaking', 'honesty', 'keep', 'glued']
# ['queen', 'seemed', 'flaunting', 'natural', 'strong', 'back']
# ['sweet', 'playful', 'romantic']
# ['australian', 'winning', 'english', 'make', 'terrific', 'disguising', 'obvious']
# ['heavy', 'dong', 'provides', 'perspective', 'intelligent', 'human']
# ['solid', 'lump', 'derives', 'sticking']
# ['diverted', 'best', 'lightens', 'leaving']
# ['interesting', 'see', 'goodall', 'bigger']
# ['intended', "it's", 'merely', 'blandly', 'cinematic', 'surgical', 'makes']
# ['somewhat', 'crudely', 'constructed', 'questing', 'racked', 'becomes', 'enemy']
# ['jean', 'fassbinder', 'perhaps', 'even', 'nocturnal', 'goya']
# ['get', "'a'", 'wears', 'b']
# ['striking', 'ending', 'long', 'go', 'fully', 'understand', 'sexual', 'involved']
# ['admirable']
# ['best', 'early', 'clashes']
# ['beautiful']
# ['unabashedly', 'schmaltzy', 'thoroughly', 'enjoyable', 'true']
# ['thoughtful', 'painful', 'made']
# ['good', 'mixed', 'ó', 'disapproval', 'combined', 'understanding']
# ['ming', 'taken', 'refined', 'crystalline']
# ['purely', 'unabashed', 'nonetheless', 'likely', 'inadvertently', 'timely', 'invaluable', 'implicit', 'foreign', 'played']
# ['trimmed', 'lavish', 'old', 'enough', 'satisfy', 'grown']
# ['get', 'truly', 'unique', 'cross', 'hollywood', 'possibly', 'fictionalize', 'believed']
# ['equally', 'admirably', 'uncommercial']
# ['mesmerizing', 'exceedingly', 'hard']
# ['dangerous', 'altar', 'take', 'painfully', 'true']
# ["moore's", 'impresses', 'almost', 'much', 'safe']
# ['spy', 'novel', 'put', 'footnote', 'brought', 'light', 'keeps', 'guessing', 'first', 'frame', 'last']
# ['true']
# ['brilliantly', 'updated', 'grasped', 'composing', 'sorrowful', 'hilarious', 'alienated', 'absurdist']
# ['quite', 'fresh']
# ['enjoy', 'nonthreatening', 'thrilling']
# ['many', 'infuriating', 'least', "amy's", 'absorbed']
# ['best']
# ['great', 'good', 'still', 'makes', 'much', 'better', 'typical']
# ['polished', 'korean', 'political', 'good', 'bad']
# ['portrayed', 'quiet', 'christian', 'truly', 'singular', 'slightly', 'magnified', 'vex', 'nearly']
# ['impeccable', 'penetrates', 'rawness', 'unflinching', 'lead', 'testud', 'parmentier', 'give', 'superlative']
# ['absorbing', 'stress', 'well', 'keen', 'unsentimental', 'theme']
# ['admired', 'particularly', 'unexpected', 'ending']
# ['aroused', 'old', 'new', 'set', 'strange', 'stark', 'lovingly', 'perceptively', 'filmed', 'almost', 'desiccated']
# ['remarkably', 'accessible']
# ['never', 'hit', 'kooky', 'yet', 'shadowy', 'sustains', 'daring', 'inventive']
# ['triumph', 'art']
# ['knew', 'spin', 'think', "he'd", 'turn']
# ['engaging', 'intimate', 'realistic', 'greatly', 'moving', 'silberstein', 'large', 'attached', 'full', 'warmth']
# ['complex', 'important', 'also', 'believe', 'immensely', 'entertaining', 'david', 'still', 'much']
# ['additional', 'interesting', "doesn't", 'magical', 'beginning', 'new', 'still', 'love', 'old']
# ['mama', 'takes', 'long', 'find', 'rhythm', 'third', 'somewhat', 'melodramatic', 'ribald', 'touching', 'nostalgia', 'sure', 'jim', 'new']
# ['buy', 'definitely', 'want']
# ['provides', 'hermetic']
# ['shapelessly', 'gratifying', 'invites', 'pick', 'even', 'admit', 'somehow', 'hit', 'live']
# ['astute', 'appraisal', 'middle', 'american', 'musical', 'desperate']
# ['makes', 'happy', 'anyway']
# ['thoughtful', 'moving', 'faces', 'difficult', 'honesty']
# ['greatest', 'romantic']
# ['call', 'good', "it's", 'good', "it's", 'good']
# ['strong', 'dong', 'remember']
# ['brimming', 'volumes', 'human', 'find', 'easily', 'crush', 'forever']
# ['steven', 'succeeded', 'focusing', 'intently', 'making', 'quirky', 'rather', 'fun']
# ['ultimately', 'stands', 'forth', 'important', 'abuses', 'oppressive']
# ['soft', 'percolating', 'deadpan']
# ['well', 'made', 'often', 'lovely', 'friendship']
# ['using', 'figurative', 'even', 'handed', 'ideological', 'continues', 'longer', 'still', 'ahead']
# ['understands', 'much', 'defines']
# ['lively', 'fun', 'unapologetically', 'dumb']
# ['witness', 'several', 'greek', 'american', 'happily', 'testify', 'comparative']
# ['ever', 'possible', 'say', 'truly', 'inhabited']
# ['presenting', 'impossible', 'impossible', 'pumpkin', 'say', 'impossible', 'confront', "what's", 'possible', 'make']
# ['impressive', 'first', 'especially', 'considering', 'background']
# ['incendiary', 'deeply', 'thought', 'provoking', 'look', 'peculiarly', 'venomous', 'increasingly', 'frightening']
# ['top', 'get', 'becomes', 'emotional', 'still', 'positive', 'wrench']
# ['also', 'tempered', 'prove', 'direct', 'gets', 'right']
# ['solid', 'affecting', 'exactly', 'thought']
# ['dazzlingly', 'assured', 'directorial', "it's", 'hard', 'know', 'first']
# ['holds', 'true', "wilde's", 'absolutely', 'polished', 'sophisticated']
# ["nch's", 'genuine', 'makes', "film's", 'occasional']
# ['thankfully', 'rapidly', 'deteriorating', 'takes', 'cheek', 'even', 'pushes', 'croc']
# ['ultimately', 'seems', 'sexual', "life's"]
# ['good', 'old', 'shamelessly', 'loves', 'mostly', 'martha', 'perfect', 'satisfy']
# ['enough', 'archival', 'talking', 'simply', 'sublime']
# ['absurdist', 'mostly', 'humor', 'gentle', 'occasionally', 'cloying', 'iranian']
# ['wonderful', 'based']
# ['interesting', 'hear']
# ['endearingly', 'offbeat', 'romantic', 'great', 'cute']
# ['unique', 'undeniable']
# ['old', 'terribly', 'original', 'rather', 'messy', 'love', 'big', 'dumb', 'happy', 'big', 'greek']
# ['almost', 'impossible', 'moved', "movie's", 'stirring', 'soviet']
# ['exactly', 'godard', 'images', "don't", 'add']
# ['balanced', 'reflective']
# ['cast', 'fine', 'bishop']
# ['change', 'america', 'full', 'necessary', 'accessible', 'makes', 'complex', 'understandable', 'looking', 'energetic']
# ['striking', 'largely', 'celebratory', 'permeates', 'ikea']
# ["you're", 'set', 'goofy', 'entertain', 'gross', 'bawdy']
# ['somewhat', 'blurred', 'sharp']
# ['wisely', 'rejects', 'make']
# ['interested', 'ram', 'seeking']
# ['intriguing', 'beautiful', 'read', 'likely', 'disappointed']
# ['new', 'guy']
# ['savvy', "america's"]
# ['legendary', 'irish', 'borstal', 'given', 'loving', 'screen', 'transferral']
# ["film's", 'greatest', 'much', 'spy']
# ['clever', 'caper', 'worthy', 'david', 'enormous']
# ["it's", 'saddest', 'ever', 'seen', 'still', 'manages', 'uplifting', 'overly', 'sentimental']
# ['usual', 'brilliant']
# ['even', 'rough', 'safely', 'sanded', 'american', 'still', 'pretty', 'darned', 'good']
# ['know', 'precisely', 'make', 'steven', 'full', "didn't", 'stop', 'enjoying', 'much']
# ['tug', 'much', 'snapshot', 'modern']
# ['nearly', 'surreal', 'dabbling', 'french', 'simple', 'taking', 'enjoyed', 'creamy', 'ultimate']
# ['say', "it's", 'slow', 'say', 'act', 'real', "wouldn't", 'say', 'alias', 'betty', 'predictable']
# ['anna', 'italian', 'aspiring', 'happens', 'worst']
# ['roman', 'never', 'become', 'heck', 'ñ', 'based', 'certainly', 'keeping']
# ['breezily', 'apolitical', 'documentary']
# ['high', "it's", 'emotionally', 'engrossing', 'strong', 'credible', 'whole']
# ['finally', 'genre', 'couple', 'less']
# ["it's", 'much', 'enjoyable', 'enlightening', 'listen', 'new', 'previous', 'able', 'make', 'impact']
# ['rare', 'want', 'invite', 'gawk', 'applaud', 'special', 'wants', 'thankfully']
# ['philosophical', 'personal', 'first', 'palatable', 'intended']
# ['natural', 'matter', 'longing']
# ['bold', 'lyrical', 'first', 'amari', 'expands', 'pat', 'aged', 'wanna', 'fun', 'rousing', 'sensual']
# ['easier', "andersson's", 'rigorous', 'personal', 'distanced']
# ['gone', 'wild', 'gone', 'civil']
# ['allowed', 'uncommonly', 'human', 'almost', 'real', 'live', 'complete']
# ['least', 'still', 'ultimately', 'satisfying', 'think']
# ['brutal', 'strangely', 'soulful']
# ['always', 'remains', 'movingly', 'genuine']
# ['intelligent', 'learning', 'cultural']
# []
# ['remarkable']
# ['follow', 'rewarded', 'brutal', 'committed', 'huppert']
# ['involving', 'true', 'chinese', 'takes', 'winds', 'acted', 'mostly', 'actual', 'involved']
# ['thought', 'provoking', 'intricate', 'intellectual']
# ['terrific', 'american', 'quaid', 'athletic']
# ['high', 'drumming', 'marching', 'excellent', "story's", 'little', 'weak']
# ['compelling', 'somewhat', 'weakened', 'leading']
# ['amazingly', 'perceptive', 'supportive', 'unsentimental']
# ['whole', 'freaky']
# []
# ['attal', 'comedy', 'serious', 'seemingly', 'serene']
# ['represented', 'feeling', 'repetitious', 'appropriately', 'brief', 'running']
# ['fine', 'made', 'richer', 'making', 'somehow', 'richer']
# ['giving', 'focused', 'illuminated']
# ['even', "can't", 'correctly', 'appreciate', 'much', 'transcends', 'ethnic']
# ['really', 'alienating', "'bartleby'", 'effectively', 'makes']
# ['thankfully', 'manages', 'outshine', 'successfully', 'plays', 'weary']
# ['conditioned', 'getting', 'weepy', 'eyed', 'downy', 'cheeked', 'empathetic', 'probably', 'feel', 'emotionally', 'cheated', "film's", 'free']
# ['personal', 'tough']
# ['intriguing', 'entertaining']
# ['expected', "sayles'", 'smart', 'sharp', 'ever', 'though', 'overshadowed', 'strong']
# []
# ['weber', 'weissman', 'insight', 'cockettes', "weren't", 'much', 'sexual', 'political', 'simply', 'triumph', 'indomitable', 'human', 'connect']
# ['damn', 'good', "isn't", 'great']
# ['unbelievably', 'leading', 'away']
# ['top', 'ostentatious', 'got']
# ['poignant', 'powerful', 'narrative', 'reading', 'writing', 'arithmetic', 'learn']
# ['nicely', 'serves']
# ['boisterous', 'heartfelt']
# ['touching', 'based', 'true', 'troubled', 'african', 'quest', 'yearning']
# ['sexy', 'gorgeous', 'pushed', 'pulled', 'literally', 'figuratively', 'makes', 'arousing', 'good']
# ['absorbing', 'andrÈ']
# ['celebrated', 'slight', 'winning', 'glossy', 'glib', 'hard']
# ['unforgettable', 'deeply', 'absorbing']
# ['singles', 'award', 'worthy', 'expect', 'less']
# ['love', 'means', 'probably', 'love']
# ['particular', 'enthusiast', 'international', 'designed', 'make', 'cultural', 'rhythmic', 'want']
# ['energetic', 'boldly', 'provocative']
# ['back', 'major']
# ["it's", 'album', 'want']
# ['rare', 'satisfies', 'lust', 'fast', 'paced', 'whole']
# ['adulthood', 'fraught', "there's", 'much', 'small', "can't"]
# ['fresh', 'written', 'produced', 'directed', 'much', 'authentic']
# []
# ['end', 'watchful']
# ['liked', 'notting', 'funeral', 'bridget', 'diary', 'high', 'want', 'miss']
# ['gentle', 'melding', 'makes', 'true']
# ['romanek', 'constantly', 'taut', 'reflecting', "character's", 'metaphorical', 'visual']
# ['whole', 'heartedly', 'recommend', 'see', 'historical', 'alone']
# ['else', 'needs']
# ['longley', 'constructed', 'remarkably', 'horrifically', 'vivid', 'snapshot', 'turbulent']
# ['cliched', 'crowd', "pleaser's", 'fresh', 'energetic', 'good', 'natured', 'often', 'infectious']
# ['often', 'gruelling', 'heartbreaking', 'raise', 'far', 'level', 'usual']
# ['go', 'enjoy']
# ['impress', 'even', 'little']
# ['proves', "he's", 'quite', 'talented', 'shows', "he's", 'dangerous']
# ['implied', 'metropolis']
# ['murderous', 'well', 'comprehensive', 'also', 'strike', 'closest']
# ['dogtown', 'z', 'funny', 'aggressive', 'alive', 'watch', 'see', 'next']
# ['green', 'go', "it's"]
# ['reilly', 'burke', 'octopus', 'fear', 'right', 'charisma']
# ['deceivingly', 'simple', 'grows']
# ['vibrant', 'individual', 'makes', 'successful', 'accessible']
# ['skillful', 'little']
# ['witty', 'take', 'uses', 'make', 'acceptance']
# ['uses', 'hit', 'miss', 'aesthetic', 'often', 'enough', 'keep', 'entertaining', 'even', 'makes', 'lick']
# ['wonderful', 'lead', 'campbell', 'leave', 'aware']
# ['long', 'running', 'never', 'feels', "there's", 'bathroom']
# ['bullock', 'good', 'working', 'natural']
# ['precious', 'artfully', 'camouflaged', 'everyday']
# ['kinnear', 'gives', 'tremendous']
# ['best', 'lucas', 'take', 'special']
# ['written', 'well', 'even', 'simple', 'near', 'takes', 'whole']
# ['intriguing', 'snapshot', "it's", 'bad']
# ['creates', 'killed']
# ['pretty', 'good', 'myriad']
# ['familiar', 'exudes', 'nostalgic', 'fresh', 'free', 'usual', 'seems', 'happening', 'first']
# ['represents', 'better', 'average', 'making', "doesn't", 'distracted']
# ['charming', 'yet', 'poignant', 'irrevocable', 'bind']
# ['enchanting', 'spectacular', 'anxious', 'express', 'new', 'magic']
# ['helps', 'moonlight', 'mile']
# ['humble', 'spiced', 'wry', 'especially', 'morgan', 'redgrave']
# ['aquatic', 'baja', 'california', 'engrossing', 'imax']
# ['dark', 'also', 'surprisingly', 'funny']
# ['popping', 'visual']
# ['dynamite', 'still', 'worth']
# ['impressive', 'though', "film's", 'open', 'ended', 'refuses', 'entirely', 'close', "characters'", 'emotional']
# ['ride', 'hyper', 'lively', 'enjoyable']
# ['bringing', 'unforced', 'rapid', 'referencing']
# ['polished', 'relatively', 'sincere']
# ['back', 'elegant', 'rare', 'warned', "it's", 'slow']
# ['whole', 'looks', 'much', 'fun', 'slapstick', 'silly', 'street', 'tossing', 'obscure', 'compact']
# ['freaky', 'crew', 'wonder', 'imagining', 'alive', "it's", 'sly', 'wink', 'becoming', 'postmodern', 'made', 'sardine', 'warped']
# ['long', 'leave', "you'll", 'wondering', 'happen', 'wishing', 'best', 'mean']
# ['still', 'pretentious', 'filled', 'entertaining', 'enough', 'recommend', 'looking', 'different']
# ['cried', 'animated', 'sweet']
# ['notorious', 'vulgar']
# ['inspiring', 'affecting', 'desperate', 'vietnamese', 'living', 'u', 'keep', 'alive']
# ['displayed', 'old', 'first', 'considering', 'subject']
# ['splendid', 'young', 'accomplished', 'fullness', 'comes', 'experience']
# ['live', 'releasing', 'cinematic', 'unearthed', 'rare']
# ['seems', 'facile', 'earlier', 'terrible', 'care']
# ['kiss', 'classic', 'destined', 'completely', 'forgotten', 'open', 'crowd', 'check', 'form']
# ['account', 'frida', 'finest', 'unfortunately', "they're", 'sandwiched', 'impossibly', 'dry', "kahlo's", 'imaginable']
# ['rending', 'honest', 'unaffected', 'gentle']
# ['clear', 'reminding', "it's", 'true', "you're", 'likely']
# ['enough', 'tale', 'make', 'far', 'satisfying', 'almost', 'recent']
# ['festival', 'obsessed', 'descend', 'utah', 'january', 'next', 'great', 'declared', "it's", 'really', 'next', 'pretty', 'good']
# ['working', 'articulate', 'favored']
# ['serious', 'filled', 'heavy', 'always', 'enticing']
# ['really', 'sunday', 'connects', 'visceral']
# ['less', 'supply', 'enough', 'close', 'calls', 'double', 'satisfy']
# ['hilarious', 'romantic']
# ['fantastic', 'makes', 'worth']
# ['ranging', 'funny', 'shattering', 'featuring', 'best', 'personal', 'plenty', 'dramatic']
# ['seeing', 'repeated', 'bourne', 'proves', 'fresh', 'always', 'possible']
# ['quiet', 'freak']
# ['get', 'spike', 'brown', 'american', 'long', 'last', 'gives', 'subject', 'worthy']
# ['feel', 'saga', 'falling', 'makes', 'spine', 'tingle']
# ['great', 'knows', 'great', 'always', 'make', 'yet', "he's"]
# ['best', 'examples', 'artful', 'large', 'filmmaking', 'likely', 'anytime', 'soon']
# ['narcotizing', 'nearly', 'sinister', 'biennial', 'biennial']
# ['well', 'written', 'nicely', 'acted', 'beautifully', 'shot', 'scored', 'several', 'openly', 'questioning', 'social', 'ensnaring', 'emotional']
# ['hoary', 'deprecating', 'sense', 'makes']
# ['utilizes', 'making', "kahlo's", 'breathing', 'often', 'catapulting', 'artist', "isn't", 'new', "it's", 'done', 'never', 'vividly', 'much']
# ['impressive', 'flawed', 'real']
# ['intelligent', 'restrained', 'coming']
# ['sick', 'twisted', 'truly']
# ['disturbing', 'brilliant']
# ['opening', 'tour', 'modern']
# ['best', 'examples', 'subject', 'fully', 'aware', 'examined', 'much', 'know', 'taken']
# ['far', 'still', 'feel', 'beating']
# ['prove', 'female', 'make', 'soft', 'sugar', 'coating', 'unrelentingly', 'claustrophobic', 'unpleasant']
# ['seems', 'realize', 'intuitively', 'even', 'reduced']
# ['mesmerizing', 'filled']
# ['fisher', 'bared', 'confronted', 'shortcomings', 'feels', 'human', 'true']
# ['right', "everyone's"]
# ['scale', 'get', "he's", 'super']
# ['makes', 'serious', 'involved']
# ['exhilarating']
# ['cuddly', 'sequel', 'hit', 'little', 'visually', 'polished', 'little', 'funnier', 'little']
# ['super', 'fleeting', "they'll", 'strongly', 'still', 'retains', 'soft']
# ['exhilarating', 'liberated', 'unexpected', 'depths']
# ['even', 'sterile', 'yet', 'compulsively', 'watchable', 'sordid', 'star', 'bob']
# ['full', 'back', 'felt', 'unforgettably', 'uncertain']
# ['predictably', 'heartwarming', 'suffused']
# ['sound', 'first', 'desperately', 'seeking', 'madonna', "doesn't"]
# ['much', 'first', 'based', "rowling's", 'phenomenal', 'best', 'second', 'go', 'round', 'possesses', 'quite', 'pleasing', 'headlong', 'likably', 'delinquent']
# ['take', 'honestly', 'nice', 'little', 'takes', 'young', 'urban', 'south', 'minds']
# ['inexorably', 'becomes', 'increasingly', 'mesmerizing']
# ['surprisingly', 'effective']
# ['ingratiating', "it's", 'sometimes', 'clever', 'always', 'interesting', 'enough', 'see']
# ['runs', 'equal', 'comes', 'experience']
# ['old', 'wonder', 'spun', 'afresh']
# ['rarely', 'films', 'come', 'along', 'intelligent', 'exuberant', 'moving']
# ['scarcely', 'needs', 'enjoy', 'colorful']
# ['quite', 'funny']
# ["it's", 'often', 'infuriatingly', 'glib', 'yet', 'made', 'great', 'evident', 'manages', 'deliver', 'even', 'unknowing']
# ['inspired']
# ['boisterous', 'cruel', 'chinese', 'terrible']
# ['elling', 'really', 'couple', 'crazy', "it's", 'therapeutic']
# ['never', 'sinks']
# ['irresistible', 'rousing', 'good', 'set', 'truly', 'grand']
# ['denying', 'physically', 'spectacular', 'emotional']
# ['resolute', 'emotional']
# ['exquisitely', 'acted', 'masterfully', 'preciously', 'interwovenÖ', 'fascinating', 'intelligent', 'intermingling', 'local']
# ["stevenson's", 'fiercely', 'committed', 'volatile']
# ['fine', 'go']
# ['shaky', "kaufman's", 'still', 'memorable', 'great']
# ['head', 'makes', 'firmly', 'held']
# ['exhilarating', 'cinematic', 'gets', 'even', 'better']
# ['higher', 'mary', 'recent']
# ['stimulates', 'higher', 'well', 'libido']
# ['sensitive', 'expertly', 'acted', 'little', 'broad', 'unabashedly', 'sentimental']
# ['sharp', 'often', 'mischievous']
# ['fine', 'best', 'extends', 'warm', 'unfamiliar', 'illuminates', 'fully', 'allows', 'larger', 'journey', 'unobtrusively']
# ['almost', 'stand', 'alone', 'perfectly', 'realized', 'behavior']
# ['psychologically', 'rich', 'suspenseful', 'moral', 'stellar']
# ['believe', 'much', 'laugh', "who's", 'casting']
# ["version's", 'still', 'plentiful']
# ['used', 'geared']
# ['provide', 'biting', 'suspense', 'credible', 'relying', 'pretentious']
# ['tried', 'fail', 'perhaps', 'explode', 'level', 'right']
# ['sincere', 'exploit', 'honest']
# ['bombing', "glass'", 'evocative', 'ultimately', 'leaves', 'task', 'divining']
# ['serious', 'finds', 'lay', 'bare', 'setting', 'good']
# ['depressing', "don't", 'object', 'unelected', 'suspected', 'incurious', 'uncharismatic', 'overgrown', 'mean', 'wide']
# ['gives', 'emotional', 'glad', 'went']
# ['sure', 'always', 'bad']
# ['lighthearted', 'feel', 'good', 'honored', 'truth', 'powerful']
# ['stopping', 'recipe']
# ['seen', 'especially', "aren't", 'aware', 'forgotten', 'unmentioned']
# ['warm', 'genuine', 'lie', 'dishonesty', 'genuinely', 'believe', "it's", 'bring', 'loved']
# ['surprising', 'new', 'familiar', 'amalgamating', 'adding', 'true', 'human']
# ['hokey', 'super', 'definitely', 'back', 'laughs', 'little', 'get', 'fuzzy']
# ['pleasant', 'romantic']
# []
# ['delivered', 'undoubted', 'stylistic', 'managed', 'sound']
# ['point', 'simple', 'obvious', 'particularly', 'eccentric', 'particularly', 'eccentric', 'subjects']
# ['romantic', 'yes', 'think', 'working', 'hard']
# ['vividly', 'pleasures', 'top']
# ['weak', 'manipulative', 'pencil', 'thin', 'miraculously', 'able', 'anyway']
# ['pro', 'overcomes', 'much', 'excessive', 'moral', 'appealing', 'lead']
# ['first', 'sparklingly', 'inventive', 'always', 'fast', 'furious', 'go', 'happily', 'along']
# ['poetic', 'ravishing', 'draggy']
# ['smartest']
# ['effectively', 'feeds', 'chilling', 'completely', 'numbing']
# ['love', 'took', 'really', 'take', 'great', 'faith']
# ['denzel', 'lean', 'engaging']
# ['tell', 'know', 'deciding', 'see']
# ['quiet', 'gives', 'honest', 'lived']
# ['teasing', 'relentless', 'good', 'bad', 'interesting', 'enough', 'even', 'interesting', 'less', 'symmetrical', 'less', 'obviously', 'shaped']
# ['stunning', 'making']
# ["it's", 'necessary', 'political', 'fascinating', 'documentary']
# ['hilarious', 'acidic']
# ['serviceable', "doesn't", 'really', 'deliver', 'delicious', 'guilty', 'better']
# ['ironic', 'unaccustomed']
# ["it's", 'affirming', 'ó', 'liked']
# ['several', 'shy', 'gross', 'expects', 'current', 'teen']
# ['inherent', 'gives', 'coming', 'well', 'warmth']
# ['led', 'smartly', 'nuanced', 'cast']
# ['everlasting', 'delicate', 'romantic', 'philosophical']
# ['gentle', 'blend', 'present', 'surviving', 'burstein', 'historical', 'telling']
# ['capturing', 'brief', 'era', 'arena', 'surely', 'cannot', 'last']
# ['elizabeth', 'barrett', 'browning', 'nancy', 'drew', 'directed', 'neil']
# ['uneven', 'intriguing', 'homage', 'remake', 'italian']
# ['celebrates', 'human', 'emotional']
# ['never', 'huge', "dickens'", 'surprised', 'much', 'watching', "mcgrath's"]
# ['best', 'show', 'mind', 'creative', 'operates']
# ['failed', 'divine', 'ya', 'ya', 'sisterhood', 'dithering']
# ['pretty', 'dicey', 'unexpected']
# ['compellingly', 'watchable']
# ['skillfully', 'evoke', 'holds', 'many', 'urban']
# ['projected', 'provide', 'spell', 'casting', 'russell', 'dreyfus', 'romantic', 'preciously', 'exposed']
# ['especially', 'tough', 'charitable']
# ['romantic', 'steeped', 'atmosphere', 'wartime', 'ably', 'captures', 'moral']
# ['divine', 'ya', 'ya', 'exactly', 'divine', "it's", 'definitely', 'defiantly', 'ya', 'terrific', 'spirited']
# ['viewed', 'better', 'average', 'true', "stevenson's", 'novel', 'likely', 'faithful', 'live', 'swashbuckling', 'classic']
# ['sobering']
# ['resourceful', 'ingenious']
# ['solid', 'filmmaking']
# ['historical', 'scope']
# ['noisy', 'cocky', 'need']
# ['editing', 'tighter', 'sympathetically', 'captures', 'often', 'futile', 'lifestyle', 'young', 'modern']
# ['comes', 'closer', 'actress', 'personifying', 'yes', 'intimidating']
# ['worth', 'watching', 'following']
# ['rather', 'lifetime', 'special', 'sweet', 'forgettable']
# ['elevated', 'deft', 'well', 'known', 'narrative']
# ['singular', "it's", 'also', "year's", 'sweetest']
# ['contemplative', 'gradually', 'artfully', 'draws', 'personal', 'political', 'fatally', 'intertwined']
# ['aggressively', 'impressive', 'american', 'makes', 'quieter']
# ['watching', 'old', 'format', 'surreal', 'enough']
# ['memorable', 'self', 'fragile', 'spiritual', 'least', 'invade']
# ["emperor's", 'new', 'begins', 'simple', 'well', 'least', "that's"]
# ['fanatically', 'fetishized', 'old', 'idiosyncrasy', 'monastic', 'sure', 'applaud', 'committed']
# ['steeped', 'majesty', 'writing', 'produces', 'new']
# ["doesn't", 'quite', 'fit', 'pumpkin', 'definitely', 'unique', 'modern']
# ['played', 'aching', 'brings']
# ['exciting', 'involving', 'smart', 'satisfying', 'inside', 'tumultuous']
# ['sometimes', 'gross', 'surprisingly', 'appealing', 'animated', 'true']
# ['incarnates', 'prophetic', 'even', 'exacting', 'admire']
# ['sometimes', 'old', 'fashioned']
# ['short', 'egoyan', "characters'", 'seriousness']
# ['impossible', 'patronized', 'iranian']
# ['quite', 'moving', 'resolutely', 'dramatic']
# ['disreputable', 'whole', 'makes', 'irresistible']
# ['exceedingly', 'clever', 'great', "don't", "see'", 'much', 'terrifying', 'coupled', 'stupendous']
# ['carefully', 'structured', 'tortured', 'unsettling', 'unquestionably', 'alive']
# ['quietly', 'reflective', 'melancholy', 'new', 'eventful', 'old', "girl's"]
# ['funny', 'heartwarming', 'digitally', 'animated']
# ['solid', 'watchable', 'first']
# ['exposes', 'generally', 'sad', 'providing', 'precious', 'insight']
# ['wide', 'ranging', 'done', 'supposedly', 'liberal', 'intimate', 'ultimately', 'tragic', 'maverick']
# ['maybe', 'still', 'made', 'great', 'scary']
# ['pleasant', 'enough', 'found']
# ['forceful', 'screen', 'even', 'softest', 'angry']
# ['far', 'less', 'sadistic', 'usual', 'typical', 'furious', 'full', 'imaginative']
# ['compelling', 'exotic', 'fast', 'shakespeare']
# ['makes']
# ['warm', 'makes', 'preposterous', 'lying', 'reasonably']
# ['powerful', 'set', 'ever', 'find', 'far', 'painfully', 'marginal']
# ['went', 'gunning', 'great']
# ['skip', 'see', 'first']
# ['best', "he's", 'getting', 'busy', "that's", 'really']
# ['enough', 'playful', 'set', 'embracing', 'wholesome']
# ['punch', 'love', 'wanted', 'much', 'actually', 'sometimes', "that's", 'enough']
# ['good', 'humored', 'ethnic', 'numerous', 'deeper', 'expected']
# ['holds', 'together', 'engaging', 'warm']
# ['deeply', 'weird', 'charmingly', 'dear']
# ['depicting', 'steeped', 'conflicts', 'symbolic']
# ['predictable', 'enough', 'make', 'sound', 'biting', 'much', 'right', 'difficult', 'get', 'really', 'peeved']
# ["it's"]
# ['incredibly', 'low', 'brings', 'together', 'sweet', 'charming', 'little']
# ["it's", 'cinematic', 'good', 'even', "it's", 'claws', 'surprisingly', 'deep']
# ['pan', "doesn't", 'much', 'weigh', 'simply', 'presents', 'works']
# ['lacks', 'depth', 'makes']
# ['tight', 'easy']
# ['full', 'lacks', 'thematic', 'largely', 'makes', 'experimental', 'still', "i'm", 'quite', 'sure']
# ['rich', 'gorgeously', 'shot', 'beautifully', 'acted', 'les', 'quiet', 'epic', 'inventive', 'refreshingly', 'unusual']
# ['beginning', "lohman's", 'deeply', 'emotional', 'shine', 'bogus']
# ['really', 'need', 'minute', 'tell', 'exactly', 'romantic', 'old', 'old']
# ['deserves', 'remembered', 'crafting', 'wonderful', 'conflicted']
# ["film's", 'running', 'shy', 'overkill', 'exhausted', 'onscreen']
# ['expect', 'checklist']
# ['adapted', 'novel', 'directed', 'alan', "napoleon's", 'interesting', 'parisian']
# ['hungry', 'need', 'pg', 'rated', 'nonthreatening', 'go', 'much']
# ['warm', 'gentle', 'romantic', 'enough', 'interesting', 'fill', 'several', 'ample', 'win', 'hard', 'hearted']
# ['marvel', 'becoming', 'ensnared']
# ['happy', "cinema's", 'idiosyncratic', 'instead']
# ['complex', 'affecting', 'uniquely', 'almodÛvar', 'strong', 'question', 'deepest', 'moral', 'right', 'wrong']
# ['good', 'urban']
# ['much', 'big', "isn't", 'favorite', 'still', 'enjoyed', 'enough']
# ["it's", 'honest', 'ever', 'made']
# ['walking', 'halfway', 'encourage', 'stand', 'undoubtedly', 'leave', 'engaged', 'ferocious', 'come']
# ['cinematic', 'successfully', 'showcases', 'novelist']
# ['silly', 'photographed', 'rather', 'good']
# ['works', 'well', 'appeal', 'even', "aren't", 'familiar']
# ['troubling', 'powerful']
# ['good', 'good', 'expect', 'light', 'romantic', 'good', 'shocked']
# ['big', 'seeming', 'slow', 'pretentious', 'thinks', 'gamble', 'worth']
# ['youthful', 'high', 'remains', 'captivating', 'religious', 'romantic', 'backed', 'likable']
# ["it's", 'sophisticated', 'challenging', 'filmmaking', 'noticeable', 'emotional', 'welcome', 'dead', "director's", 'previous', 'full']
# ['funny', 'handles', 'courting']
# ['always', 'helps', 'earnest', 'overcome', "parker's", 'creative']
# ['much', 'lies', 'utter', 'cuteness', 'animated', 'faces', 'expressive']
# ['follows', 'closely', 'established', 'giant', 'died', "movie's"]
# ['anchored', 'terrific', 'shows', 'knows', 'continental']
# ['awkward', 'sincere', 'ultimately']
# ['extraordinary', 'american', 'seem', 'fully', 'aware', 'fame', "it's"]
# ['predictable', 'never', 'feels', 'emotional']
# ['sam', 'became', 'lucky', 'wilco', 'got', 'dropped', 'proving', "another's"]
# ['thankfully', 'understated', 'drawn', 'excellent']
# ['perfect']
# ['leading', 'couple', 'screen', 'eating', 'susan', 'sarandon', 'best', 'even', 'goes', 'easily']
# ['undercover', 'brother', 'definitely', 'also', 'full', 'sharp', 'smart']
# ['gets', 'skin', 'lost']
# ['last']
# ['talking']
# ['high', 'literary', 'stunning', 'applauded']
# ['terrific', 'dazzling', 'dancing']
# ['inspirational', 'diverse', 'human', 'spiritual']
# ['fairly', 'aware']
# ['beautiful']
# ['tailored']
# ['moving']
# ['full', 'nonstop', 'starts', 'overkill']
# ['astonishing']
# ['greatly', 'less', 'manic', 'cho', 'appears', 'settled', 'comfortably']
# ['first', 'several', 'allen', 'surpassed', 'spun', "leoni's"]
# ["isn't", 'quite', 'equal', 'best', 'earlier', "it's", 'easily', 'finest', 'american', 'comes', 'close', 'recapturing']
# ['leads']
# ['earnest', 'ball', 'pauses', 'blunt', 'make', 'sure', 'getting', 'metaphysical']
# ['modest', 'ease']
# ['diverting', 'conventional', 'well', 'acted', 'tale', 'locked', 'ongoing']
# ['accomplished', 'amazing', 'technical']
# ['teen', 'go', 'orange']
# ['makes', 'seem', 'romantic', 'maggie']
# ['deliciously', 'mordant', 'bitter', 'black']
# ['much', 'feel', 'good', 'cast', 'polished', 'delightfully', 'piquant', 'aged']
# ['risky', 'intelligent', 'romantic', 'rapturous']
# ['much', 'closer', "hornby's", 'dead', 'confessional', 'high']
# ['ramble', 'idoosyncratic', 'often', 'dealt', 'loose', 'lackadaisical']
# ['spiced', 'speak', 'advises', 'rather', 'er', 'bubbly', 'alien', 'witty', "silver's", 'replaced', 'cute', 'alien']
# ['raw', 'disturbing', 'took', 'make', "trio's", 'absorbing', 'narrative', 'wrenching', 'indeed']
# ['beautiful', 'haunting', 'tell', 'make']
# ['aside', 'funniest', 'andrew', "niccol's", 'brilliant', 'wickedly', 'eccentric']
# ['handily', 'directs', 'sustains', "hook's", 'remarkable', 'first']
# ['fish', 'barely', 'stays']
# ['much', 'comes', 'brave', 'uninhibited', 'lead']
# ['resisting', 'romp', 'rarely', 'provides']
# ['often', 'forgotten', 'remarkably', 'varying', 'human', 'using', 'creative', 'natural']
# ['ignites', 'gripping']
# ["it's", 'hard', 'seduced', 'even', 'run', 'drive']
# ['old', 'preteen', 'worship', "lil'"]
# ['refreshingly', 'authentic', 'coming']
# ['fourth', 'animated', "won't", 'convert', 'even', 'keep', 'open', 'fun', 'meeting', 'new', 'called']
# ['big', 'opening', 'elmer', 'perfectly', 'melodic', 'gets']
# ['seen', 'inch', 'local', 'educational', 'steve', 'priceless']
# ['shambling', 'cheerfully', 'inconsequential']
# ['entire', 'makes', 'given', 'frame', 'made', 'christmas']
# ['dancing', 'fabulous', 'slow', 'repetitive', 'enough', 'keep']
# ['incredibly', 'superbly', 'paced', 'filled']
# ["there's", 'much', 'nick', 'novel', 'pleasurable', 'featherweight']
# ['belated', 'nod', 'neglected', 'standing', 'motown', 'cultural', 'best', 'revealing', 'richly', 'entertaining']
# ['even', "ride's", 'little', 'final', 'suspiciously', 'smooth', 'gotta', 'give', 'best', 'known', 'superfluous', 'trying']
# ['distinctive', 'even', 'humorous', 'stand', 'clearly', 'made']
# ['script', 'confidence', 'many', 'spend', 'entire', 'trying']
# ['moving']
# ['ofrece', 'una']
# ['ingenious', 'entertaining', "i've", 'seen', 'quite', 'long']
# ['clever']
# ['vivid', 'cinematic']
# ['hilarious', 'touching', 'wonderfully', 'dyspeptic']
# ['espectacular', 'simple', 'sencillamente']
# ['simple', 'warming', 'full']
# ['enjoyable', 'pretty', 'much', 'aimed', 'loves']
# ['frisky', 'fresh', 'romantic', 'exporing', 'sexual']
# ["it's", 'good', 'classic', 'odd', 'entertaining', 'authentic']
# ['flavorful', 'romantic', 'call', 'got', 'groove', 'back', 'ever']
# ['happily', 'chin', 'unhappily', 'invisible', 'wrote', 'script', 'human', 'hoped']
# ['lewis', 'hilarious']
# ['amusingly', 'contrived', 'outlandish', 'ever', 'mistake', 'resembling']
# ["'they", 'make']
# ['little', 'different', 'shading', 'makes']
# ['fessenden', 'much', 'creating']
# ['comic', 'especially', 'lee', "ross's", 'ken']
# ['compelling', 'best', 'finest']
# ['nearly', 'whole', 'safe', 'less', 'sum']
# ['makes', 'examine', 'much', 'supposed']
# ['bold', 'subversive', 'popular', 'powerful', 'high', 'speaking', 'spellbinding', 'entrancing']
# ['pretty', 'darn', 'good', 'smarty']
# ['young', 'smart']
# ["woo's", 'distinct', 'collide', 'balletic', 'underlying']
# ['created', 'wacky']
# ['ending', 'unfulfilled', 'enjoy', 'memorable', 'ensemble']
# ['agreeable', 'wasting', "pal's", 'low', 'still', 'epochs']
# ['brave', 'universal', 'zippy', 'sampling']
# ['unusual', 'inherent', 'also', 'haphazard', 'public', 'whole']
# ['think', 'entranced', 'appalled', 'asian']
# ['refreshing', 'see', 'robin', 'turn', 'string', 'insultingly', 'innocuous', 'sappy', "he's", 'making', 'last', 'several']
# ['making', 'first', 'heaving', "puccini's", 'famous', 'fandango', 'great', 'cinematic']
# ["lilia's", 'sensual', 'superficially', 'preposterous', 'abbas', 'unimpeachable', 'emotional']
# ["frida's", 'artistic', 'undeniable', 'breathtakingly', 'designed', "i've", 'ever', 'seen']
# ['perfect', 'sick', 'snide']
# ['divide', 'separate', 'reaching', 'begging']
# ['nervy', 'sensitive', 'taps', 'genuine', 'artistic', 'scathing']
# ['marvellous']
# ['big', 'gorgeous', 'taking']
# ['sharp', 'lively', 'funny', 'ultimately', 'sobering']
# ["film's", 'certainly', 'earthshaking', 'fluctuating', 'female', 'winning']
# ['worthy', 'great', 'humanitarian']
# ['recent', 'favourite', 'white', 'even', 'unlucky', 'never', 'owned']
# ['recording', 'enlightening', 'appreciative', 'level']
# ['occasionally', 'funny', 'consistently', 'odd', 'works', 'reasonably', 'well', 'star']
# ['bright', 'seems', 'alternately', 'amused', 'disgusted', 'throwing']
# ['enhance', "film's", 'otherworldly', 'giving', 'strange', 'combo', 'disorienting', 'unreality', 'seemingly', 'broken', 'fourth']
# ['creates', 'disturbingly', 'familiar', 'yet', 'tremendously', 'sad']
# ['predictable', 'expected', 'hoops', 'even', 'depth']
# ['often', 'hilarious', 'well', 'importantly', 'entertaining', 'fascinating', 'document', 'seen', 'believed']
# ['emotionally', 'rich', 'poetically', 'plump', 'visually', 'fulsome', 'never', 'reinforced', 'brilliantly', 'personified']
# ['inviting']
# ["film's", 'real', 'adventure', 'enjoy', 'thinking', 'compelling', 'easy']
# ['nearly', 'impeccable', 'cinematic', 'wonderful', 'triumph', 'akin']
# ['deviant', 'topical', 'funny']
# ['startling', 'fresh', 'still', 'remains', 'ambiguous', 'chinese']
# ['highly', 'intriguing', 'coupled', 'ingenious', 'lavishly', 'built', 'tutorial', 'slash']
# ['says', 'repeatedly', "'lovely"]
# ['picking', 'apart', 'human', 'afraid', 'front']
# ['stupid', 'formulaic']
# ['best', 'good', 'refreshingly', 'adult', 'take']
# ['amazing', 'incendiary', 'straight', 'rough']
# ['nowhere', 'appropriated', 'found', 'become', 'made', 'low', 'american']
# ['occasionally', 'reviewing', 'art', 'slam', 'bam', 'jaded', 'critic', 'truly', 'new']
# ['little', 'bleep', 'many', 'check']
# []
# ['holds', 'goodwill', 'close', 'relatively', 'slow']
# ['well', 'oiled', 'exquisitely', 'polished', 'upholstered']
# ['perfect', 'ending', 'sweet', 'hits', 'escaped', 'small']
# ['subtle', 'getting', 'skin', 'sticking', 'long']
# ['stays', 'afloat', 'hallucinatory']
# ['helps', 'central', 'experienced', 'know', 'well']
# ['provocative', 'sickness']
# ['worth']
# ['intelligent', 'romantic', 'actual']
# ['boisterous']
# ['draws', 'best', 'large', 'beautifully', 'articulated', 'subtle', 'expressive', 'poetic']
# ['utmost', 'subtlety', 'outstanding', 'eric', 'understands', 'simplicity']
# ['full', 'frontal', 'think', "he's", 'gone', 'commercial', 'nominated']
# ['cut', 'clever', 'writing', 'sprightly', 'acting']
# ['want', 'probably', 'see', 'bit', 'unfinished']
# ['intricate', 'literary', 'common']
# ['close', "we'll", 'ever', 'come', 'looking']
# ['thoughtful', 'provocative']
# ['witty', 'touching', 'well', 'paced']
# ['tells', 'lovingly', 'beautifully', "couldn't", 'captivated']
# ['follow', 'well', 'shot', 'roll']
# ['later']
# ['love', 'jealousy', 'steady']
# ['divertida', 'demencial', 'es', 'un', 'que', 'puro']
# ['psychological', 'smart', 'obsessive']
# ['often', 'hilarious']
# ['grant', 'gets', 'display', 'also', 'show', 'acting', 'surprise', 'hearted']
# ['funny', 'candidly', 'revealing', "it's", 'intriguing', 'put']
# ['exude']
# ['effective', 'documentary', 'israeli', 'occupied', 'palestinian']
# ['little', 'lit', 'extremely', 'well', 'played', 'often', 'funny']
# ['laughs', "'types'", 'many', 'many', 'recognize', 'even', 'play']
# ['real', 'real', 'living', 'concerned', 'future', 'elderly', 'mentally', 'handicapped']
# ['absolutely', 'spooky', 'shagster', 'right', 'original', 'furnished']
# ['cast', 'solid', 'ensemble', "isn't", 'weak']
# ['smart', 'grown', 'false']
# ["it's", 'refreshing', 'american', 'castro']
# ['often', 'moving', 'discomfort', 'inherent', 'american']
# ['controversial', 'korean', 'latest', 'offers', 'gorgeous', 'effective', 'increasingly', 'unsettling']
# ['considerable', 'personal', 'screen', 'makes', 'old', 'seem', 'new']
# ['new', 'australian', 'making', 'american', 'jazzes', 'adroitly']
# ['endearing', 'hear', 'make', 'excellent', 'least', 'conscious']
# ['often', 'achieves', 'mesmerizing']
# ['makes', 'mawkish', 'posing', 'offering', 'rousing', 'genuine']
# ['romantic', 'plenty', 'chew', 'unusual', 'slowly']
# ['occasionally', 'funny', 'always', 'colorful', 'enjoyably', 'overblown', 'traditional']
# ['effectively', 'translates', "naipaul's", 'lively', 'mix', 'page']
# ['tasty', "d'oeuvre"]
# ['become', 'cautionary', 'allowed', 'charming', 'tale', 'pleasantly', 'dramatizing']
# ['filled', 'cast', 'appealing', 'fresh', 'faces']
# ['sort', 'filmic', 'true', 'potential']
# ['get', 'becomes', 'heady']
# ['works', 'unusual', 'playboy']
# ['subject', 'degree', 'least', 'quintessentially', 'american', 'called', 'iranian']
# ['fast', 'moving', 'remarkable', 'appears', 'destined', 'become', 'landmark', 'japanese']
# ['sour', 'little', 'ending', 'great']
# ['worthy', 'difficult']
# ['powerful', 'enough', 'leave', 'screen', 'sizzling']
# ['crazy', 'showcase', "sandler's", 'many']
# ...
# ['small', 'independent', 'suffering', 'severe']
# ['tone']
# ['alone', 'force']
# ['ultimately', "sarah's", 'finding', 'seems', 'psychotic', 'romantic', 'makes', 'convincing', 'broken', 'outweighs']
# ['supposed', 'humorous', 'human', 'look', 'hope', 'breed', 'certain', 'never', 'quite', 'adds']
# ['rejected', 'episode', 'credible', 'puzzling', 'real', 'happening']
# ['portray', 'ultimate', 'create', 'ultimate', 'black', 'ultimate', 'fi', 'whiffle']
# ['enigmatic', 'good', "it's", 'solving']
# ['painful', 'obnoxious']
# []
# ['clearly', 'means', 'exclusively', 'converted']
# ['take', 'mormon', 'sappy', 'preachy']
# ['definitely', 'crowd', 'roman']
# ['certainly', 'good', 'horrible']
# ['bad', 'feel', 'running', 'eventually', 'works', 'merely', 'bad', 'rather', 'painfully', 'awful']
# ['tame', 'even', 'slightly', 'wised', 'quickly', 'change']
# ['appears', 'modeled', 'worst', 'clichÈs', 'dredge']
# ['costume', 'bigger']
# ['takes', 'somewhere', "you're", 'likely', 'seen', 'beneath', 'exotic', 'exotic', 'surprisingly', 'old', 'fashioned']
# ['better', 'focused', 'incomprehensible', 'anne', 'based', 'queen', 'damned', 'meandering', 'tortured', 'woe']
# ['turns', 'affected']
# ['good', 'looking', 'ultimately', 'pointless', 'political', 'almost']
# ['tired', 'predictable', 'bordering', 'offensive']
# ["isn't", 'quite', "generation's", "it's", 'discernible', 'feeling', 'chest', "it's"]
# ['stealing', 'swipe', 'offer', 'precisely', 'recompense', 'early', 'scattered', 'thin', 'repetitious']
# ['insultingly', 'inept', 'artificial', 'impacts']
# ['much', 'think', 'central', 'behan', 'bisexual', 'took']
# ["live'", 'almost', 'expected', 'taken', 'comedian']
# ['simpering']
# ['never', 'decides', 'wants', 'black', 'melodrama']
# ['become', 'apparent', "franchise's", 'best', 'long', 'past']
# ['impossible', 'makes', 'serial']
# ['el', 'del', 'padre', 'anti', 'catholic', "it's"]
# ['better', 'described', 'ghost', 'gone', 'badly', 'awry']
# ['bad', 'superficially', 'written', 'ramble', 'tediously', 'lives', 'loves', 'art', "they're", 'struggling']
# ['playing', 'big', 'new', 'figure', "don't"]
# ['competently', 'directed', 'terminally', 'cute']
# ['big', 'finish', 'getting', 'excited', 'biting', 'finding', 'filling', 'missing']
# ['unlikable', 'disturbing', 'disgusting', 'redeeming']
# ['virtually', 'unwatchable']
# ['eternally', 'devoted', 'black', 'intermittently', 'good', 'feel', 'free', 'go', 'get', 'popcorn']
# ['self', 'serious', 'makes', 'well', "isn't", 'much']
# ['exhausted', 'desiccated', 'get']
# ['main', 'simply', 'named', 'emphasizing', 'disappointingly', 'generic', 'entire']
# ['execution', 'unfocused']
# ['sticking', 'fresh']
# ['lives', 'glossy', 'resembles', 'formulaic', 'mainstream']
# ['undergo', 'radical']
# ['na', 'punctuated', 'graphic']
# ['run', 'clever', 'ideas', 'visual', 'halfway']
# ['spy', 'lucy', 'liu', 'never', 'comes', 'together']
# ['made', 'posing', 'real']
# ['upside', 'given', 'feardotcom', 'minimal']
# ['imitating', 'imitating', "it's", 'unhappy', 'around']
# ['uneasy', 'raunchy', 'seemingly', 'sincere', 'personal']
# ['told', 'heavy', 'irish', 'accentuating', 'rather', 'muting', "plot's"]
# ['running', 'empty', 'repeating', 'already', 'done', 'often']
# ['lax', 'limp', 'seen', 'worn']
# ['literally', 'stops', 'hard', 'still', "won't", 'feel', 'longest', 'going']
# ['serious', 'go', 'perfect']
# ['aptly', 'named', 'shimmering', 'beautifully', 'costumed', 'filmed']
# ['preposterously', 'melodramatic', 'brooklyn', 'circa']
# ['fatal', 'Ω', 'even', 'indecent', 'stolid']
# ['standard', 'spat', 'tinseltown', 'assembly']
# ['extraordinarily', 'silly']
# []
# ['gaping', 'sink', 'standard']
# ["isn't", 'necessarily', 'bad', 'frequently', 'misses']
# ['beautiful', 'solemn', 'cannot', 'disguise', 'gorgeous', 'soundtrack', 'drown', 'righteousness']
# ['top', 'dialogue', 'often', 'spittingly', 'funny']
# ['painfully', 'bad', "'fully", "experienced'", "it's", 'tediously', 'bad', 'fully', 'forgotten']
# ['charly', 'comes', 'emotionally', 'manipulative', 'sadly', 'imitative', 'innumerable']
# ['great', 'talented', 'kaige', 'chosen', 'make', 'english', 'poorly', 'plotted', 'scripted']
# ['good', 'able', 'overcome']
# ['classic', 'moral', 'done', 'survive', 'laudable', 'justify', 'theatrical']
# ['social', 'political', "doesn't", 'inspiring', 'insightful']
# ['really', 'exceptional', 'running']
# ['little', 'stylish', 'true', 'serves', 'rather', 'thin', 'moral', 'knowing', 'fable']
# ['nonstop', 'ultimately', 'proves', 'tiresome', 'failing', 'compensate', 'thin', 'facile']
# ['monumental', 'practically', 'filmmaking', 'idiotic', 'annoying', 'heavy', 'handed', 'visually', 'atrocious', 'often', 'downright']
# ['putting', 'french', 'romantic', 'sure', 'severely', 'amÈlie']
# ['overburdened', 'complicated', 'plotting', 'banal']
# ['ensemble', 'depend', 'empathy', "ain't"]
# ['falls', 'sketch', 'saturday']
# ['yet', 'consciously', 'overwritten', 'characters', 'miss', 'go', 'wrong']
# ['screenplay', "isn't", 'nearly', 'surprising', 'enough', 'reasonable']
# ['really', 'advantage', 'invest', 'animatronic', 'acting']
# ['successful', 'relating', 'creating', 'emotionally', 'complex', 'dramatically', 'satisfying']
# ['obvious', 'preposterous', 'likely', 'set', 'back']
# ["it's", 'hard', 'becomes', 'ravishing', 'waif', 'applying', 'smear', 'rather', 'sees']
# ['virulently', 'unpleasant', 'romantic']
# ['discloses', 'almost']
# ['minor', 'remake', 'longest']
# ['hot', 'direct', 'given']
# ['earnest', 'american', 'enough', 'put', 'away', 'sell', 'amp', 'apply', 'medical']
# ['witted', 'lazy', 'animal', 'documentary', 'crocodile']
# ['putting', 'tell', 'know', "queen's"]
# ['even', 'ismail', 'suspect', 'hard', 'sitting']
# ['really', 'silly', 'hollywood', 'multitude', 'minded', 'yahoo', 'ing']
# ["it's", 'particularly', 'good', 'monsterous']
# ['needs', 'passionate', 'scorsese', 'need', 'new']
# ['enchanted', 'low', 'liberally', 'seasoned', 'emotional', 'sorely', 'missing', 'however', 'edge', 'wild', 'lunatic', 'best']
# ['deja', 'appropriate', "it's", 'likely', 'thought', 'first', 'pro', "you'll", 'likely', 'think']
# ['impossible']
# ["chung's", 'rather', 'unexceptional', 'even', 'irritating', 'least', 'western', 'making', 'awfully', 'hard', 'complicated', 'develops', 'central']
# ['unimaginative', 'romantic', "i've", 'ever', 'seen']
# ["there's", 'purpose', 'even', 'handedness', "film's", 'rigged', 'sluggish']
# ['unfortunately', 'actually', 'watching', 'compelling', 'making']
# ['zoning', 'protect', 'dullest', 'opening']
# []
# ['resolutely', 'downbeat', 'indie', 'trick']
# ['rather']
# ['far', 'fetched', 'convoluted', 'thematic', 'destiny', 'redemptive']
# ['ethereal', 'ends', 'seeming']
# ['hoping', 'sleazy']
# ['supposed', 'comes', 'pretty', 'dull']
# ['soulless', 'even', 'damning', 'virtually', 'xxx']
# ['boring', 'normally', 'good', 'even', 'made', 'bad']
# ["queen's", 'throwback', 'fails', 'many']
# ['keep', 'pushing', 'expense', 'character', 'fall', 'apart']
# ['rather', 'real', 'elling', 'bjarne', 'become', 'symbolic', 'supposed', "naÔf's", 'encounter']
# ['gives', 'saw', 'glitter']
# ["it's", 'sit', 'stare', 'turn', 'away', 'instead', 'talking', "it's", "you're"]
# ['suspect', 'bored', 'watching', 'morvern', 'callar', 'go', 'pack', 'knitting']
# ['engaging', "don't", 'even']
# ['think', 'uh', 'michael', 'supposed', 'written', 'ever', 'saw', 'written']
# ['brooding', 'slow', 'takes', 'central', 'seriously']
# ['necessary']
# ['cinematic', 'patronizing', 'favored', 'pretentious', 'untalented', 'enjoy', 'moaning']
# ['indeed', 'sit', 'open', 'mouthed', 'screaming']
# ['light', 'focusing', 'ultimately', 'make', 'bigger']
# ['catholic', 'help', 'jewish', 'get', 'heaven', 'sending', 'straight']
# ['tired', 'really', 'poor', 'comedic', 'got', 'huge']
# ['lovely', 'trifle', 'unfortunately', 'little']
# ['really', 'need']
# ['get', 'funny', 'simply', 'structuring', 'setup', 'stealing', "can't", 'even', 'much', 'immediately', 'succumbs', 'earth']
# ['fun', 'playing', 'obvious', 'try', 'guess', 'gored']
# ['spied', 'little', 'mediocre', 'occasionally', 'inspired']
# ['much', 'comic', 'perverse', 'watching']
# ['easy', 'genuinely', 'satisfying']
# ['bearable', 'barely']
# ['less', 'funny', 'less', 'funny']
# ['sporadic', 'liveliness', 'slapstick', 'pleasing']
# ['feeble']
# ['awful', 'emotionally', 'malleable']
# ['Öthe', 'far', 'flung', 'illogical', 'plain', 'stupid']
# ['simple', 'seems', 'simple', 'working', 'almost', 'arbitrary']
# ['concerning', 'chronically', 'mixed', 'african', 'american', 'get', 'overachieving', 'intriguing', 'supernatural', 'obscure']
# ['familiar', 'told', 'countless', 'italian', 'chinese', 'irish', 'latin', 'indian', 'russian', 'american', 'young', 'struggling', 'conflicting', 'cultural']
# ['ardently', 'christian', 'never', 'question']
# ['essentially', 'weak', 'strong']
# ['bombastic', 'ultimately', 'empty', 'ii']
# ['looking', 'realizing', 'serving', 'even', 'halfway']
# ['long', 'larded', 'somber', 'cop', 'ultimately', 'feels', 'flat', 'titular']
# ['leaves', 'cold', 'undermines', 'phenomenal']
# ['ho', 'always', 'watchable', 'yet', 'hardly', 'memorable']
# ['swiftly', 'deteriorates', 'terribly', 'obvious', 'rough', 'lead']
# ['still', 'eludes', 'playing', 'merely', 'charmless']
# ['attractive', 'also', 'difficult']
# ['suitably', 'kooky', 'appeal', 'strip', 'often', 'enough', 'keep', 'alert', 'amused']
# ['technically', 'well', 'made', 'abrupt', 'races', 'finish', 'proves', 'simply', 'discouraging', 'let']
# ['tedious', 'contains', 'almost', 'enough']
# ["it's", 'released']
# ['absolutely', 'unintentionally', 'terrifying']
# ['eckstraordinarily', 'lame', 'severely', 'boring']
# ['legged', 'falls', 'flat']
# ['matter', 'much', 'accepting', 'old']
# ["you'll", 'wondering', "lee's", 'go', 'save']
# ['crossing', 'mumbo', 'jumbo', 'manipulative', 'sappy']
# ['lighten', 'heavy', 'subject', 'silberling', 'also', 'certain', 'trivializes', 'many', 'nervous']
# ['brilliant', 'charismatic', 'rampant']
# ['uncomfortably', 'close', 'pro']
# ['staggeringly', 'dreadful']
# ['like', 'high', 'flog', 'dead', 'surprising', 'trying', 'new']
# ['final', 'seen']
# ['throwing', 'pulling', 'seems', 'ransacked', 'old', 'ii', 'overly', 'familiar']
# ['good', 'told', "can't", 'handle', 'truth', 'high', 'poetically', 'states']
# ['sad', 'resonant', 'spinning', 'run', 'lola', 'turned', 'softheaded', 'metaphysical']
# ['feeling', 'rode', 'eating', 'extra', 'large']
# ['little', 'tired', 'maybe', 'original', 'run']
# ['go', 'long', 'anxious', 'see', 'strange', 'young', 'strange', 'guy']
# ['full', 'frontal']
# ['intellectual', 'made', 'framed', 'drama', 'real', 'less', 'sophisticated', 'mistake', 'endorsement', 'bean']
# ['big', 'small', 'shriveled']
# ['greenlight', 'sappy']
# ['gets', "don't", 'ask', 'tell', 'laughed', 'bad']
# ['cast', 'high', 'little']
# ['use', 'good']
# ['many', "it's", 'acceptable', 'entire', 'especially', 'fit']
# ['hollywood', 'satire', 'deeper', 'oh', 'entertaining']
# ['pile', 'useless', 'mtv', "don't", 'know', 'tell']
# ['made', 'careful', 'well', 'acted', 'spader', 'felt', 'disrespected']
# ['well', 'made', 'hearted']
# []
# ['strictly', 'routine']
# ['real']
# ['skillful', 'shyamalan', 'undone']
# ['new', 'much', 'catching', 'drenched', 'stephen', 'norrington', 'directed', 'new', 'returning', 'much', 'sillier']
# ['sporting', 'worst', 'recent', 'cinematic', 'ballistic', 'vs', 'also', 'features', 'terrible', 'banal', 'hole', 'superficial', 'rather', 'dull', 'unimaginative']
# ['first', 'loose', 'jointed', 'loud', 'far']
# ['barely', 'adequate', 'older', 'got', 'give']
# ['cast', 'crew', 'burn', 'negative', 'pretend', 'whole', 'never', 'existed']
# ['throws', 'away', 'goodwill', 'first', 'generates', 'orchestrating', 'finale', 'impenetrable']
# ['really', 'renting', 'interested', "you're", 'interested']
# ['get']
# ['uneven', 'funny', 'quite', 'enough']
# ['sepia', 'tinted', 'heavy', 'surround', 'sound', 'moaning']
# ['singles', 'ward', 'cameos', 'automatically', 'equal']
# ['campy', 'make', 'mel', 'belt', 'schtick', 'sophisticated']
# ['probably', 'limited', 'undemanding', 'armchair']
# ['seems', 'fried']
# ['cherish', 'worked', 'better', 'short']
# ['manipulative', 'plain', 'old', 'take', 'besotted', 'obvious', 'tells', 'new']
# ['arnold', 'stretched', 'barely', 'feature', 'little', 'paid', 'still', 'updated', 'dickensian', 'craig', "bartlett's"]
# ['true', 'relentlessly', 'nasty', 'pay', 'considerable', 'looking']
# ["doesn't", 'come', 'close', 'justifying', 'surrounded', 'festival', 'ago']
# ['thin', "aren't", 'interesting', 'enough', 'go', 'daily', 'whole']
# ['never', 'especially', 'clever', 'often', 'rather', 'pretentious']
# ['move', 'honest', 'want', 'see', 'flick', 'due']
# ['damned', 'long', 'little', 'going']
# ['mr', 'tries', 'shift', "thriller's"]
# ['even', 'passing', 'political', 'loads', 'try', 'escape', 'documentary', 'sealed']
# ['still', 'top', 'heavy', 'cheatfully', 'filmed', 'martial', 'disintegrating', 'jagged', 'serve', 'purpose', 'call']
# ['attraction', 'gets', 'drunk', 'sober', 'transparent', 'moralizing']
# ['many', 'tense', 'trapped', 'prove', 'distressing']
# ['least', 'see', 'study', 'wide', 'range', 'limited']
# ['strangely', 'hollow', 'emotional']
# []
# ['entered', 'bizarre', 'adrian', 'holds', 'sway', 'simultaneously', 'broadly', 'metaphorical', 'oddly', 'abstract', 'excruciatingly', 'literal']
# ['high', 'soon', 'proves', 'preposterous', 'acting', 'robotically', 'italicized', 'advertising', 'take', 'little', 'hustling']
# ['adds', 'takes', 'great', 'turns', 'mundane']
# ['sacrificed', 'sake']
# ['say', 'pretty', 'much', 'go', 'talking', 'ridiculous']
# ["it's", 'ends', "doesn't", 'horribly', 'wrong']
# ['shadyac', 'glumly', 'mishandle', 'promising', 'needs']
# ['difficult', 'confused', 'less', 'interesting', 'sloppily', 'made', 'possibly', 'come']
# ['tuck', 'goes']
# ['pedestrian']
# ['nice', 'often', 'play', 'blown', 'big']
# ['feel', 'bad', 'ending', 'depressing', 'bunch', 'hot', "viewer's", 'asks', 'seen', 'winking', 'social']
# ['somewhere', 'sling', 'blade', 'south', 'west', 'billy', "bob's"]
# ['intellectually', 'scary', 'dramatically', 'involving']
# ['inconsequential', 'barely', 'piffle']
# ['abiding', 'mild', 'hallucinogenic', 'overwhelming', 'haute', 'quite', 'conceal', 'resembling']
# []
# ['come', 'away', 'thinking', 'bright', 'worth', 'caring', 'maybe', 'molly', 'dysfunctional', 'deserve']
# ['provocative', 'often', 'viewer', 'left', 'puzzled']
# ['much', 'devoid', 'appears', 'edited']
# ['much', 'enough']
# ['build', 'horrified', 'awe', 'simple', 'virtually']
# ["it's", 'provocative', 'speculative', 'hampered', "taylor's", 'cartoonish', 'considered', 'shaped', 'random']
# ['remake', 'classic', 'fabulous', 'crossroads', 'never', 'much', 'worse', 'better']
# ['muddled', 'trashy']
# ['need', 'agile', 'dull', 'light', 'rodan']
# ['narc', 'atmosphere']
# ['excessively', 'tiresome', 'verbally', 'pretentious', 'handful', 'redeeming', 'long']
# ['juliet', "stevenon's", 'bring', 'emotional', 'enough', 'desperately', 'needs']
# ["it's", 'tough', 'startled', "you're", 'almost']
# ["nelson's", 'needs', 'serious', 'working', 'rather', 'stage', 'shouting']
# ['nearly', 'humorless', 'chore', 'first', 'lead']
# ['terrible', 'nevertheless', 'find', 'moving']
# ['many', "waster'", 'surely']
# ['crocodile', 'hurried', 'badly', 'cobbled', 'combined', 'japanese', 'canned', 'commenting', "monster's"]
# ['made']
# ['well', 'made', "it's", 'dry']
# []
# train on 7998 instances, test on 2666 instances
# accuracy: 0.705926481620405
# pos precision: 0.6942675159235668
# pos recall: 0.735933983495874
# neg precision: 0.7190742218675179
# neg recall: 0.6759189797449362
# Most Informative Features
#               engrossing = True              pos : neg    =     16.3 : 1.0
#                    quiet = True              pos : neg    =     15.0 : 1.0
#                inventive = True              pos : neg    =     12.3 : 1.0
#                     dull = True              neg : pos    =     12.2 : 1.0
#             refreshingly = True              pos : neg    =     11.7 : 1.0
#                     flat = True              neg : pos    =     11.0 : 1.0
#               delightful = True              pos : neg    =     11.0 : 1.0
#                absorbing = True              pos : neg    =     11.0 : 1.0
#               refreshing = True              pos : neg    =     10.3 : 1.0
#                 provides = True              pos : neg    =     10.2 : 1.0

# %%
#empty array#
contentArray =['Starbucks is doing very well lately.',
               'Overall, while it may seem there is already a Starbucks on every corner, Starbucks still has a lot of room to grow.',
               'They just began expansion into food products, which has been going quite well so far for them.',
               'I can attest that my own expenditure when going to Starbucks has increased, in lieu of these food products.',
               'Starbucks is also indeed expanding their number of stores as well.',
               'Starbucks still sees strong sales growth here in the united states, and intends to actually continue increasing this.',
               'Starbucks also has one of the more successful loyalty programs, which accounts for 30%  of all transactions being loyalty-program-based.',
               'As if news could not get any more positive for the company, Brazilian weather has become ideal for producing coffee beans.',
               'Brazil is the world\'s #1 coffee producer, the source of about 1/3rd of the entire world\'s supply!',
               'Given the dry weather, coffee farmers have amped up production, to take as much of an advantage as possible with the dry weather.',
               'Increase in supply... well you know the rules...',]


exampleArray = ['The incredibly intimidating NLP scares people away who are sissies']
               

def processContent(sentence):
    try:
        for item in sentence:
            tokenized = nltk.word_tokenize(item)
            tagged = nltk.pos_tag(tokenized)

            print(tagged)

    except Exception as e:
        print(str(e))
    return (tagged)


x = processContent(exampleArray)
# Out:
# [('The', 'DT'), ('incredibly', 'RB'), ('intimidating', 'VBG'), ('NLP', 'NNP'), ('scares', 'NNS'), ('people', 'NNS'), ('away', 'RB'), ('who', 'WP'), ('are', 'VBP'), ('sissies', 'NNS')]
