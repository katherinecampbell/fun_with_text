# %%
import csv
import random
import math
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def loadDataset(filename, split, trainingSet=[] , testSet=[]):
	with open(filename, 'r') as csvfile:
	    lines = csv.reader(csvfile)
	    dataset = list(lines)
	    for x in range(len(dataset)-1):
	        for y in range(4):
	            dataset[x][y] = float(dataset[x][y])
	        if random.random() < split:
	            trainingSet.append(dataset[x])
	        else:
	            testSet.append(dataset[x])

# %%
def euclideanDistance(instance1, instance2, length):
	distance = 0
	for x in range(length):
		distance += pow((instance1[x] - instance2[x]), 2)
	return math.sqrt(distance)

# %%
def getNeighbors(trainingSet, testInstance, k):
	distances = []
	length = len(testInstance)-1
	for x in range(len(trainingSet)):
		dist = euclideanDistance(testInstance, trainingSet[x], length)
		distances.append((trainingSet[x], dist))
	distances.sort(key=operator.itemgetter(1))
	neighbors = []
	for x in range(k):
		neighbors.append(distances[x][0])
	return neighbors

# %%
def getResponse(neighbors):
	classVotes = {}
	for x in range(len(neighbors)):
		response = neighbors[x][-1]
		if response in classVotes:
			classVotes[response] += 1
		else:
			classVotes[response] = 1
	sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
	return sortedVotes[0][0]

# %%
def getAccuracy(testSet, predictions):
	correct = 0
	for x in range(len(testSet)):
		if testSet[x][-1] == predictions[x]:
			correct += 1
	return (correct/float(len(testSet))) * 100.0

# %%
splits =[0.9, 0.75, 0.67, 0.5, 0.34, 0.25]

# %%
# prepare data
split_9=[]
trainingSet=[]
testSet=[]
split = 0.9
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_9.append(accuracy)
    #print('Accuracy: ' + repr(accuracy) + '%')
split_9
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-bf74bbf7a7bf> in <module>()
#       4 testSet=[]
#       5 split = 0.9
# ----> 6 loadDataset('iris.csv', split, trainingSet, testSet)
#       7 print('Train set: ' + repr(len(trainingSet)))
#       8 print('Test set: ' + repr(len(testSet)))
#
# <ipython-input-136-e699a3f9f76a> in loadDataset(filename, split, trainingSet, testSet)
#       5             for x in range(len(dataset)-1):
#       6                 for y in range(4):
# ----> 7                     dacataset[x][y] = float(dataset[x][y])
#       8                 if random.random() < split:
#       9                     trainingSet.append(dataset[x])
#
# NameError: name 'dacataset' is not defined

# %%
# prepare data
split_75=[]
trainingSet=[]
testSet=[]
split = 0.75
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_75.append(accuracy)
    #print('Accuracy: ' + repr(accuracy) + '%')
split_75
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-5469e4e49eae> in <module>()
#       4 testSet=[]
#       5 split = 0.75
# ----> 6 loadDataset('iris.csv', split, trainingSet, testSet)
#       7 print('Train set: ' + repr(len(trainingSet)))
#       8 print('Test set: ' + repr(len(testSet)))
#
# <ipython-input-136-e699a3f9f76a> in loadDataset(filename, split, trainingSet, testSet)
#       5             for x in range(len(dataset)-1):
#       6                 for y in range(4):
# ----> 7                     dacataset[x][y] = float(dataset[x][y])
#       8                 if random.random() < split:
#       9                     trainingSet.append(dataset[x])
#
# NameError: name 'dacataset' is not defined

# %%
# prepare data
split_67=[]
trainingSet=[]
testSet=[]
split = 0.67
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_67.append(accuracy)
    #print('Accuracy: ' + repr(accuracy) + '%')
split_67
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-09a81c761520> in <module>()
#       4 testSet=[]
#       5 split = 0.67
# ----> 6 loadDataset('iris.csv', split, trainingSet, testSet)
#       7 print('Train set: ' + repr(len(trainingSet)))
#       8 print('Test set: ' + repr(len(testSet)))
#
# <ipython-input-136-e699a3f9f76a> in loadDataset(filename, split, trainingSet, testSet)
#       5             for x in range(len(dataset)-1):
#       6                 for y in range(4):
# ----> 7                     dacataset[x][y] = float(dataset[x][y])
#       8                 if random.random() < split:
#       9                     trainingSet.append(dataset[x])
#
# NameError: name 'dacataset' is not defined

# %%
# prepare data
split_5=[]
trainingSet=[]
testSet=[]
split = 0.5
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_5.append(accuracy)
    print('Accuracy: ' + repr(accuracy) + '%')
split_5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-e0fe95b749b9> in <module>()
#       4 testSet=[]
#       5 split = 0.5
# ----> 6 loadDataset('iris.csv', split, trainingSet, testSet)
#       7 print('Train set: ' + repr(len(trainingSet)))
#       8 print('Test set: ' + repr(len(testSet)))
#
# <ipython-input-136-e699a3f9f76a> in loadDataset(filename, split, trainingSet, testSet)
#       5             for x in range(len(dataset)-1):
#       6                 for y in range(4):
# ----> 7                     dacataset[x][y] = float(dataset[x][y])
#       8                 if random.random() < split:
#       9                     trainingSet.append(dataset[x])
#
# NameError: name 'dacataset' is not defined

# %%
# prepare data
split_34=[]
trainingSet=[]
testSet=[]
split = 0.34
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_34.append(accuracy)
    #print('Accuracy: ' + repr(accuracy) + '%')
split_34
# Out:
# Train set: 46
# Test set: 103
# k= 1
# k= 3
# k= 5
# k= 10
# k= 15
# k= 20
# [93.20388349514563,
#  93.20388349514563,
#  93.20388349514563,
#  93.20388349514563,
#  93.20388349514563,
#  93.20388349514563]

# %%
# prepare data
split_25=[]
trainingSet=[]
testSet=[]
split = 0.25
loadDataset('iris.csv', split, trainingSet, testSet)
print('Train set: ' + repr(len(trainingSet)))
print('Test set: ' + repr(len(testSet)))
# generate predictions
predictions=[]
k_val = [1,3,5,10,15,20]
for j in range (0,6):
    k = k_val[j]
    print('k=', k)
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    split_25.append(accuracy)
    #print('Accuracy: ' + repr(accuracy) + '%')
split_25
# Out:
# Train set: 41
# Test set: 108
# k= 1
# k= 3
# k= 5
# k= 10
# k= 15
# k= 20
# [96.29629629629629,
#  96.29629629629629,
#  96.29629629629629,
#  96.29629629629629,
#  96.29629629629629,
#  96.29629629629629]

# %%
s9 = np.array(split_9)
s75 = np.array(split_75)
s67 = np.array(split_67)
s5 = np.array(split_5)
s34= np.array(split_34)
s25 = np.array(split_25)

# %%
plt.xlabel("k value")
plt.ylabel("accuracy")
plt.title("accuracy with different splits and knns")
plt.plot(k_val, s9,label= '.9')
plt.plot(k_val, s75,label= '.75')
plt.plot(k_val, s67,label= '.67')
plt.plot(k_val, s5,label= '.5')
plt.plot(k_val, s34,label= '.34')
plt.plot(k_val, s25,label= '.25')
plt.legend()
plt.show()

# %%
# prepare data
final_array =[]
splits =[0.9, 0.75, 0.67, 0.5, 0.34, 0.25]
for i in range(0,6):
    print(i)
    split_array = []
    trainingSet=[]
    testSet=[]
    loadDataset('iris.csv', splits[i], trainingSet, testSet)
    #print('Train set: ' + repr(len(trainingSet)))
    #print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions=[]
    k_val = [1,3,5,10,15,20]
    for j in range (0,6):
        k = k_val[j]
        print('k=', k)
        for x in range(len(testSet)):
            print('x is ', x,' k is ', k)
            neighbors = getNeighbors(trainingSet, testSet[x], k)
            result = getResponse(neighbors)
            predictions.append(result)
            #print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
        accuracy = getAccuracy(testSet, predictions)
        #print('Accuracy: ' + repr(accuracy) + '%')
        split_array.append(accuracy)
    print(split_array)
    final_array.append(split_array)
final_array
# Out:
# 0
# k= 1
# x is  0  k is  1
# x is  1  k is  1
# x is  2  k is  1
# x is  3  k is  1
# x is  4  k is  1
# x is  5  k is  1
# x is  6  k is  1
# x is  7  k is  1
# x is  8  k is  1
# x is  9  k is  1
# x is  10  k is  1
# x is  11  k is  1
# x is  12  k is  1
# k= 3
# x is  0  k is  3
# x is  1  k is  3
# x is  2  k is  3
# x is  3  k is  3
# x is  4  k is  3
# x is  5  k is  3
# x is  6  k is  3
# x is  7  k is  3
# x is  8  k is  3
# x is  9  k is  3
# x is  10  k is  3
# x is  11  k is  3
# x is  12  k is  3
# k= 5
# x is  0  k is  5
# x is  1  k is  5
# x is  2  k is  5
# x is  3  k is  5
# x is  4  k is  5
# x is  5  k is  5
# x is  6  k is  5
# x is  7  k is  5
# x is  8  k is  5
# x is  9  k is  5
# x is  10  k is  5
# x is  11  k is  5
# x is  12  k is  5
# k= 10
# x is  0  k is  10
# x is  1  k is  10
# x is  2  k is  10
# x is  3  k is  10
# x is  4  k is  10
# x is  5  k is  10
# x is  6  k is  10
# x is  7  k is  10
# x is  8  k is  10
# x is  9  k is  10
# ...

# %%
final_array=np.array(final_array)
split_array = np.array(splits)
k_val = np.array(k_val)
final_array
# Out:
# array([[ 100.        ,  100.        ,  100.        ,  100.        ,
#          100.        ,  100.        ],
#        [ 100.        ,  100.        ,  100.        ,  100.        ,
#          100.        ,  100.        ],
#        [  91.83673469,   91.83673469,   91.83673469,   91.83673469,
#           91.83673469,   91.83673469],
#        [  96.15384615,   96.15384615,   96.15384615,   96.15384615,
#           96.15384615,   96.15384615],
#        [  96.84210526,   96.84210526,   96.84210526,   96.84210526,
#           96.84210526,   96.84210526],
#        [  95.23809524,   95.23809524,   95.23809524,   95.23809524,
#           95.23809524,   95.23809524]])

# %%
plt.xlabel("k value")
plt.ylabel("accuracy")
plt.title("accuracy with different splits and knns")
plt.plot(k_val, final_array[0],label= split_array[0])
plt.plot(k_val, final_array[1],label= split_array[1])
plt.plot(k_val, final_array[2],label= split_array[2])
plt.plot(k_val, final_array[3],label= split_array[3])
plt.plot(k_val, final_array[4],label= split_array[4])
plt.plot(k_val, final_array[5],label= split_array[5])
plt.legend()
plt.show()
